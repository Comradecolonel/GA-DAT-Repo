# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('../data/titanic.csv')

# %%
# make a not to work with different aggragated data sets. You want to take groups that you have and compare them to other groups
#it requires you set variables as the group and them work on those variables
# Out:
# Object `pd.groupby()` not found.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts().plot(kind = 'bar', color = ['blue','red'])

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('seaborn')

# %%
df.Embarked.value_counts().plot(kind = 'pie')

# %%
df.groupby('Sex')['Embarked'].value_counts().plot(kind = 'bar')

# %%
df[df['Sex']== 'female']['Fare'].mean()
df.groupby('Sex')['Age','Fare'].mean().plot(kind = 'bar')

# %%
df['Age'].plot(kind = 'hist', bins=20)

# %%
df.hist(column = 'Age', by = 'Embarked', color = ['red'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C53B721240>,
# ...
#       dtype=object)

# %%
df.hist(column = 'Age', by = 'Embarked', color = ['green'],layout=(1,3),figsize=(32,12))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C53D0FBAC8>,
# ...
#       dtype=object)

# %%
df.hist(column = 'Age', by = 'Embarked', color = ['green'],layout=(1,3),figsize=(12,4), sharey = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C53CAF3748>,
# ...
#       dtype=object)

# %%
df['Age'].plot(kind = 'kde')

# %%
df.plot('Age','Fare',kind = 'scatter')

# %%
df1 = pd.DataFrame(
{
    'x':np.random.randn(1000),
    'y':np.random.randn(1000)
})

# %%
df1.plot('x','y', kind = 'hexbin')
plt.savefig('hexexample.png')

# %%
fig, ax = plt.subplots(1,2)

# %%
ax
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C53E8956D8>,
# ...
#       dtype=object)

# %%
df[df.Sex == 'female'].plot('Age','Fare', kind = 'scatter', ax = ax[0])
df[df.Sex == 'male'].plot('Age','Fare', kind = 'scatter', ax = ax[1])

# %%
ay = df[df.Sex == 'female'].plot('Age','Fare', kind = 'scatter')

df[df.Sex == 'male'].plot('Age','Fare', color = 'green', kind = 'scatter', ax=ay)

# %%
sns.catplot(x='Pclass',y='Age', data=df)

# %%
sns.catplot(x='Pclass',y='Age', data=df,kind = 'swarm')
# Out:
# D:\Program Files (x86)\Anaconda\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# D:\Program Files (x86)\Anaconda\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.catplot(x='Pclass',y='Age', data=df,kind='violin')

# %%
sns.catplot(x='Pclass',y='Age', data=df,kind='boxen')

# %%
sns.catplot(x='Pclass',y='Age', data=df,kind='box')

# %%
sns.catplot(x='Pclass',y='Age', data=df,kind='bar')

# %%
sns.catplot(y='Age', data=df,kind='count')

# %%
sns.catplot(x='Pclass', y='Age',kind='swarm',hue = 'Survived',col='Sex' ,data=df)

# %%
sns.catplot(x='Pclass', y='Age',kind='swarm',hue = 'Survived',col='Sex' ,row = 'Embarked',data=df)

# %%
sns.catplot(x='Pclass',y='Age', data=df,kind='violin',palete='red')

# %%
sns.distplot(df['Fare'])

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(df)

#quick way to see teh linear relationships between variables
# Out:
# D:\Program Files (x86)\Anaconda\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# D:\Program Files (x86)\Anaconda\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.pairplot(df, x_vars=['Age','Fare','Pclass'], y_vars='Survived')
