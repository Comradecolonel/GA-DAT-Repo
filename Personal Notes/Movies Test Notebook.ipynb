# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movies\train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-0675d22db604> in <module>
# ----> 1 df = pd.read_csv('movies\train.csv')
#
# X:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  AirplaneMinimalAltitude Amphibious  ArmorFront  \
# 0           0                      NaN      False           2
# 1           1                      NaN      False           1
# 2           2                      NaN      False           2
# 3           3                      NaN      False           2
# 4           4                      NaN       True           2
#
#    ArmorFrontSplashResistant  ArmorRear  ArmorRearSplashResistant  ArmorSides  \
# 0                      False          1                     False           1
# 1                      False          1                     False           1
# 2                      False          1                     False           1
# 3                      False          1                     False           1
# 4                      False          1                     False           1
#
#    ArmorSidesSplashResistant  ArmorTop  ...  Weapon9RangeShipMinimum  \
# ...
