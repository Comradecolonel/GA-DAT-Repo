# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv("Data HW3/train.csv")
dftest = pd.read_csv("Data HW3/test.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# <h1>Beginning of data exploration</h1>

# %%
df["PoolArea"].value_counts()
# Out:
# 0      1453
# 738       1
# 648       1
# 576       1
# 555       1
# 519       1
# 512       1
# 480       1
# Name: PoolArea, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
X_train
# Out:
#       MSSubClass  OverallQual  OverallCond  YearBuilt  1stFlrSF  2ndFlrSF  \
# 0       0.073350     0.651256    -0.517023   1.050634 -0.793162  1.161454
# 1      -0.872264    -0.071812     2.178881   0.156680  0.257052 -0.794891
# 2       0.073350     0.651256    -0.517023   0.984415 -0.627611  1.188943
# 3       0.309753     0.651256    -0.517023  -1.862993 -0.521555  0.936955
# 4       0.073350     1.374324    -0.517023   0.951306 -0.045596  1.617323
# 5      -0.163054    -0.794879    -0.517023   0.719540 -0.948366  0.501703
# 6      -0.872264     1.374324    -0.517023   1.083743  1.374522 -0.794891
# 7       0.073350     0.651256     0.381612   0.057352 -0.143892  1.456967
# 8      -0.163054     0.651256    -0.517023  -1.333243 -0.363764  0.927792
# 9       3.146594    -0.794879     0.381612  -1.068368 -0.221494 -0.794891
# 10     -0.872264    -0.794879    -0.517023  -0.207523 -0.317203 -0.794891
# 11      0.073350     2.097391    -0.517023   1.116853  0.050114  1.821204
# ...

# %%
X_test
# Out:
#       MSSubClass  OverallQual  OverallCond  YearBuilt  1stFlrSF  2ndFlrSF  \
# 0             20            5            6       1961       896         0
# 1             20            6            6       1958      1329         0
# 2             60            5            5       1997       928       701
# 3             60            6            6       1998       926       678
# 4            120            8            5       1992      1280         0
# 5             60            6            5       1993       763       892
# 6             20            6            7       1992      1187         0
# 7             60            6            5       1998       789       676
# 8             20            7            5       1990      1341         0
# 9             20            4            5       1970       882         0
# 10           120            7            5       1999      1337         0
# 11           160            6            5       1971       483       504
# ...

# %%
df['PavedDrive'].value_counts()
# Out:
# Y    1340
# N      90
# P      30
# Name: PavedDrive, dtype: int64

# %%
df['MiscVal'].value_counts()
# Out:
# 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 2000        4
# 600         4
# 1200        2
# 480         2
# 1150        1
# 800         1
# 15500       1
# 620         1
# 3500        1
# 560         1
# 2500        1
# 1300        1
# 1400        1
# 350         1
# 8300        1
# 54          1
# Name: MiscVal, dtype: int64

# %%
df['WoodDeckSF'].value_counts()
# Out:
# 0      761
# 192     38
# 100     36
# 144     33
# 120     31
# 168     28
# 140     15
# 224     14
# 240     10
# 208     10
# 216      9
# 180      8
# 160      8
# 250      6
# 132      6
# 264      6
# 143      6
# 96       6
# 156      6
# 171      5
# 48       5
# 196      5
# 105      5
# 288      5
# 210      5
# 220      4
# 158      4
# 104      4
# 147      4
# 74       4
#       ...
# 183      1
# 181      1
# 179      1
# 245      1
# 255      1
# 340      1
# 304      1
# 333      1
# 327      1
# 326      1
# 325      1
# 321      1
# 312      1
# 309      1
# 307      1
# 306      1
# 305      1
# 303      1
# 257      1
# 301      1
# 298      1
# 295      1
# 294      1
# 283      1
# 278      1
# 269      1
# 265      1
# 263      1
# 260      1
# 215      1
# Name: WoodDeckSF, Length: 274, dtype: int64

# %%
df.groupby('PavedDrive')['SalePrice'].describe()
# Out:
#              count           mean           std      min       25%       50%  \
# PavedDrive
# N             90.0  115039.122222  44352.523309  34900.0   84625.0  111000.0
# P             30.0  132330.000000  33503.030228  79500.0  102750.0  132250.0
# Y           1340.0  186433.973881  79665.503047  35311.0  134337.5  168500.0
#
#                  75%       max
# PavedDrive
# N           137100.0  265979.0
# P           159100.0  215000.0
# Y           220000.0  755000.0

# %%
df.groupby('Exterior2nd')['SalePrice'].describe()
# Out:
#              count           mean            std       min       25%  \
# Exterior2nd
# AsbShng       20.0  114060.550000   42315.043608   35311.0   94000.0
# AsphShn        3.0  138000.000000   37509.998667  100000.0  119500.0
# Brk Cmn        7.0  126714.285714   38693.084161   60000.0  114000.0
# BrkFace       25.0  195818.000000   95097.551756   40000.0  137000.0
# CBlock         1.0  105000.000000            NaN  105000.0  105000.0
# CmentBd       60.0  230093.833333  116140.396221   75000.0  118375.0
# HdBoard      207.0  167661.565217   70061.078357   83000.0  130500.0
# ImStucc       10.0  252070.000000  193176.672447   88000.0  131250.0
# MetalSd      214.0  149803.172897   55078.595310   62383.0  118625.0
# Other          1.0  319000.000000            NaN  319000.0  319000.0
# Plywood      142.0  168112.387324   46955.744372   76500.0  135000.0
# Stone          5.0  158224.800000   63533.067573   90000.0   93500.0
# ...

# %%
df.groupby('Electrical')['SalePrice'].describe()
# Out:
#              count           mean           std      min       25%       50%  \
# Electrical
# FuseA         94.0  122196.893617  37511.376615  34900.0   98500.0  121250.0
# FuseF         27.0  107675.444444  30636.507376  39300.0   88500.0  115000.0
# FuseP          3.0   97333.333333  34645.827070  73000.0   77500.0   82000.0
# Mix            1.0   67000.000000           NaN  67000.0   67000.0   67000.0
# SBrkr       1334.0  186825.113193  79856.458326  37900.0  134575.0  170000.0
#
#                   75%       max
# Electrical
# FuseA       143531.25  239000.0
# FuseF       129950.00  169500.0
# FuseP       109500.00  137000.0
# Mix          67000.00   67000.0
# SBrkr       220750.00  755000.0

# %% [markdown]
# <h1>Modifying the Dataset</h1>

# %%
X_train = pd.read_csv("Data HW3/train.csv", usecols=[1, 17, 18, 19, 43, 44, 46, 49, 50, 70, 77])
y_train = df['SalePrice']

# %%
X_train.columns
# Out:
# Index(['MSSubClass', 'OverallQual', 'OverallCond', 'YearBuilt', '1stFlrSF',
#        '2ndFlrSF', 'GrLivArea', 'FullBath', 'HalfBath', 'ScreenPorch',
#        'YrSold'],
#       dtype='object')

# %%
X_train = (X_train - X_train.mean()) / X_train.std()

# %%
X_train = X_train.join(pd.get_dummies(df['MSZoning']))

# %%
X_train
# Out:
#       MSSubClass  OverallQual  OverallCond  YearBuilt  1stFlrSF  2ndFlrSF  \
# 0       0.073350     0.651256    -0.517023   1.050634 -0.793162  1.161454
# 1      -0.872264    -0.071812     2.178881   0.156680  0.257052 -0.794891
# 2       0.073350     0.651256    -0.517023   0.984415 -0.627611  1.188943
# 3       0.309753     0.651256    -0.517023  -1.862993 -0.521555  0.936955
# 4       0.073350     1.374324    -0.517023   0.951306 -0.045596  1.617323
# 5      -0.163054    -0.794879    -0.517023   0.719540 -0.948366  0.501703
# 6      -0.872264     1.374324    -0.517023   1.083743  1.374522 -0.794891
# 7       0.073350     0.651256     0.381612   0.057352 -0.143892  1.456967
# 8      -0.163054     0.651256    -0.517023  -1.333243 -0.363764  0.927792
# 9       3.146594    -0.794879     0.381612  -1.068368 -0.221494 -0.794891
# 10     -0.872264    -0.794879    -0.517023  -0.207523 -0.317203 -0.794891
# 11      0.073350     2.097391    -0.517023   1.116853  0.050114  1.821204
# ...

# %%
X_train = X_train.join(df['LotArea'])

# %%
pd.get_dummies(df['Street'])
# Out:
#       Grvl  Pave
# 0        0     1
# 1        0     1
# 2        0     1
# 3        0     1
# 4        0     1
# 5        0     1
# 6        0     1
# 7        0     1
# 8        0     1
# 9        0     1
# 10       0     1
# 11       0     1
# 12       0     1
# 13       0     1
# 14       0     1
# 15       0     1
# 16       0     1
# 17       0     1
# 18       0     1
# 19       0     1
# 20       0     1
# 21       0     1
# 22       0     1
# 23       0     1
# 24       0     1
# 25       0     1
# 26       0     1
# 27       0     1
# 28       0     1
# 29       0     1
# ...    ...   ...
# 1430     0     1
# 1431     0     1
# 1432     0     1
# 1433     0     1
# 1434     0     1
# 1435     0     1
# 1436     0     1
# 1437     0     1
# 1438     0     1
# 1439     0     1
# 1440     0     1
# 1441     0     1
# 1442     0     1
# 1443     0     1
# 1444     0     1
# 1445     0     1
# 1446     0     1
# 1447     0     1
# 1448     0     1
# 1449     0     1
# ...

# %%
X_train['Street'] = df['Street']

# %%
X_train["Street"]= X_train["Street"].replace("Pave", 1.0) 
X_train["Street"]= X_train["Street"].replace("Grvl", 0)

# %%
X_train['Utilities'] = df['Utilities']

# %%
X_train["Utilities"]= X_train["Utilities"].replace("ELO", 0) 
X_train["Utilities"]= X_train["Utilities"].replace("NoSeWa", 1.0) 
X_train["Utilities"]= X_train["Utilities"].replace("NoSewr", 2.0) 
X_train["Utilities"]= X_train["Utilities"].replace("AllPub", 3.0)

# %%
X_train["Utilities"].value_counts()
# Out:
# 3.0    1459
# 1.0       1
# Name: Utilities, dtype: int64

# %%
X_train = X_train.join(pd.get_dummies(df['LotConfig']))

# %%
X_train = X_train.join(pd.get_dummies(df['Neighborhood']))

# %%
X_train = X_train.join(pd.get_dummies(df['BldgType']))

# %%
X_train['HouseStyle'] = df['HouseStyle']

# %%
X_train['HouseStyle'] = X_train['HouseStyle'].replace("1Story", 0) 
X_train['HouseStyle'] = X_train['HouseStyle'].replace("1.5Fin", 1.0) 
X_train['HouseStyle'] = X_train['HouseStyle'].replace("1.5Unf", 2.0) 
X_train['HouseStyle'] = X_train['HouseStyle'].replace("2Story", 3.0)
X_train['HouseStyle'] = X_train['HouseStyle'].replace("2.5Fin", 4.0) 
X_train['HouseStyle'] = X_train['HouseStyle'].replace("2.5Unf", 5.0) 
X_train['HouseStyle'] = X_train['HouseStyle'].replace("SFoyer", 6.0) 
X_train['HouseStyle'] = X_train['HouseStyle'].replace("SLvl", 7.0)

# %%
X_train['BsmtCond'] = df['BsmtCond']

# %%
X_train['BsmtCond'] = X_train['BsmtCond'].replace("NA", 0) 
X_train['BsmtCond'] = X_train['BsmtCond'].replace("Po", 1.0) 
X_train['BsmtCond'] = X_train['BsmtCond'].replace("Fa", 2.0) 
X_train['BsmtCond'] = X_train['BsmtCond'].replace("TA", 3.0) 
X_train['BsmtCond'] = X_train['BsmtCond'].replace("Gd", 4.0) 
X_train['BsmtCond'] = X_train['BsmtCond'].replace("Ex", 5.0) 
X_train['BsmtCond'] = X_train['BsmtCond'].replace("unknown", 0)

# %%
X_train['HeatingQC'] = df['HeatingQC']

# %%
X_train['HeatingQC'] = X_train['HeatingQC'].replace("Po", 1.0) 
X_train['HeatingQC'] = X_train['HeatingQC'].replace("Fa", 2.0) 
X_train['HeatingQC'] = X_train['HeatingQC'].replace("TA", 3.0) 
X_train['HeatingQC'] = X_train['HeatingQC'].replace("Gd", 4.0) 
X_train['HeatingQC'] = X_train['HeatingQC'].replace("Ex", 5.0)

# %%
X_train['CentralAir'] = df['CentralAir']

# %%
X_train['CentralAir'] = X_train['CentralAir'].replace("Y", 1.0)
X_train['CentralAir'] = X_train['CentralAir'].replace("N", 0)

# %%
X_train = X_train.join(pd.get_dummies(df['GarageType']))

# %%
X_train = X_train.join(pd.get_dummies(df['SaleType']))

# %%
X_train = X_train.join(pd.get_dummies(df['SaleCondition']))

# %%
X_train['WoodDeckSF'] = df['WoodDeckSF']

# %%
X_train['OpenPorchSF'] = df['OpenPorchSF']

# %%
X_train = X_train.join(pd.get_dummies(df['Exterior1st']))

# %%
#X_train = X_train.merge(pd.get_dummies(df['Exterior2nd']),how = 'inner')

# %%
X_train['ExterQual'] = df['ExterQual']

# %%
X_train['ExterQual'] = X_train['ExterQual'].replace("Po", 1.0) 
X_train['ExterQual'] = X_train['ExterQual'].replace("Fa", 2.0) 
X_train['ExterQual'] = X_train['ExterQual'].replace("TA", 3.0) 
X_train['ExterQual'] = X_train['ExterQual'].replace("Gd", 4.0) 
X_train['ExterQual'] = X_train['ExterQual'].replace("Ex", 5.0)

# %%
X_train = X_train.join(pd.get_dummies(df['Electrical']))

# %%
df1 = X_train[X_train.isna().any(axis=1)]

# %%
df1
# Out:
# Empty DataFrame
# Columns: [MSSubClass, OverallQual, OverallCond, YearBuilt, 1stFlrSF, 2ndFlrSF, GrLivArea, FullBath, HalfBath, ScreenPorch, YrSold, C (all), FV, RH, RL, RM, LotArea, Street, Utilities, Corner, CulDSac, FR2, FR3, Inside, Blmngtn, Blueste, BrDale, BrkSide, ClearCr, CollgCr, Crawfor, Edwards, Gilbert, IDOTRR, MeadowV, Mitchel, NAmes, NPkVill, NWAmes, NoRidge, NridgHt, OldTown, SWISU, Sawyer, SawyerW, Somerst, StoneBr, Timber, Veenker, 1Fam, 2fmCon, Duplex, Twnhs, TwnhsE, HouseStyle, BsmtCond, HeatingQC, CentralAir, 2Types, Attchd, Basment, BuiltIn, CarPort, Detchd, COD, CWD, Con, ConLD, ConLI, ConLw, New, Oth, WD, Abnorml, AdjLand, Alloca, Family, Normal, Partial, WoodDeckSF, OpenPorchSF, AsbShng, AsphShn, BrkComm, BrkFace, CBlock, CemntBd, HdBoard, ImStucc, MetalSd, Plywood, Stone, Stucco, VinylSd, Wd Sdng, WdShing, ExterQual, FuseA, FuseF, FuseP, ...]
# Index: []
#
# [0 rows x 102 columns]

# %%
X_train['BsmtCond'].fillna(0,inplace=True)

# %% [markdown]
# <h1>Model Selection</h1>

# %%
from sklearn.model_selection import cross_val_score
#you can use fit and predict method from other models beside sklearn
scores = cross_val_score(estimator=rf, X=X_train, y=y_train, cv=10)

# %%
scores
# Out:
# array([0.8715765 , 0.87717222, 0.89099724, 0.76104002, 0.83762405,
#        0.8826691 , 0.86318227, 0.86757533, 0.76561249, 0.8525584 ])

# %%
scores.mean()
# Out:
# 0.8470007624497583

# %%
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()

# %%
scores2 = cross_val_score(estimator=lreg, X=X_train, y=y_train, cv=10)

# %%
scores2
# Out:
# array([ 8.74531713e-01,  8.70700606e-01,  8.86662596e-01,  7.62887685e-01,
#         8.31228275e-01,  8.43526979e-01,  7.97721170e-01, -9.03481545e+06,
#         6.33153128e-01,  8.46384536e-01])

# %%
scores2.mean()
# Out:
# -903480.8108033219

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
rreg= Ridge()
lasso = Lasso()

# %%
scores3 = cross_val_score(estimator=rreg, X=X_train, y=y_train, cv=10)

# %%
scores3
# Out:
# array([0.88057397, 0.87339785, 0.88859712, 0.76252051, 0.83273201,
#        0.85031879, 0.80564652, 0.84457179, 0.6317759 , 0.85002355])

# %%
scores3.mean()
# Out:
# 0.8220158022997573

# %%
scores4 = cross_val_score(estimator=lasso, X=X_train, y=y_train, cv=10)
# Out:
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 501632342978.77496, tolerance: 852398977.1246126
#   positive)
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 572133682308.9688, tolerance: 827439703.8697118
#   positive)
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205344278575.69678, tolerance: 829042909.2707292
#   positive)
# ...

# %%
scores4
# Out:
# array([0.87633822, 0.86615051, 0.88813687, 0.77150012, 0.82720145,
#        0.83791068, 0.80604709, 0.83735179, 0.63182776, 0.83895076])

# %%
scores4.mean()
# Out:
# 0.8181415238756568

# %% [markdown]
# <h1>Preparation of Test set</h1>

# %%
test = pd.read_csv("Data HW3/test.csv", usecols=[1, 17, 18, 19, 43, 44, 46, 49, 50, 70, 77])

# %%
test = (test - test.mean()) / test.std()

# %%
test = test.join(pd.get_dummies(dftest['MSZoning']))

# %%
test = test.join(dftest['LotArea'])

# %%
test['Street'] = dftest['Street']

# %%
test["Street"]= test["Street"].replace("Pave", 1.0) 
test["Street"]= test["Street"].replace("Grvl", 0)

# %%
test['Utilities'] = dftest['Utilities']

# %%
test["Utilities"]= test["Utilities"].replace("ELO", 0) 
test["Utilities"]= test["Utilities"].replace("NoSeWa", 1.0) 
test["Utilities"]= test["Utilities"].replace("NoSewr", 2.0) 
test["Utilities"]= test["Utilities"].replace("AllPub", 3.0)

# %%
test = test.join(pd.get_dummies(dftest['LotConfig']))

# %%
test = test.join(pd.get_dummies(dftest['Neighborhood']))

# %%
test = test.join(pd.get_dummies(dftest['BldgType']))

# %%
test['HouseStyle'] = dftest['HouseStyle']

# %%
test['HouseStyle'] = test['HouseStyle'].replace("1Story", 0) 
test['HouseStyle'] = test['HouseStyle'].replace("1.5Fin", 1.0) 
test['HouseStyle'] = test['HouseStyle'].replace("1.5Unf", 2.0) 
test['HouseStyle'] = test['HouseStyle'].replace("2Story", 3.0)
test['HouseStyle'] = test['HouseStyle'].replace("2.5Fin", 4.0) 
test['HouseStyle'] = test['HouseStyle'].replace("2.5Unf", 5.0) 
test['HouseStyle'] = test['HouseStyle'].replace("SFoyer", 6.0) 
test['HouseStyle'] = test['HouseStyle'].replace("SLvl", 7.0)

# %%
test['BsmtCond'] = dftest['BsmtCond']

# %%
test['BsmtCond'] = test['BsmtCond'].replace("NA", 0) 
test['BsmtCond'] = test['BsmtCond'].replace("Po", 1.0) 
test['BsmtCond'] = test['BsmtCond'].replace("Fa", 2.0) 
test['BsmtCond'] = test['BsmtCond'].replace("TA", 3.0) 
test['BsmtCond'] = test['BsmtCond'].replace("Gd", 4.0) 
test['BsmtCond'] = test['BsmtCond'].replace("Ex", 5.0) 
test['BsmtCond'] = test['BsmtCond'].replace("NaN", 0)

# %%
test['BsmtCond'].fillna(0,inplace=True)

# %%
test['HeatingQC'] = dftest['HeatingQC']

# %%
test['HeatingQC'] = test['HeatingQC'].replace("Po", 1.0) 
test['HeatingQC'] = test['HeatingQC'].replace("Fa", 2.0) 
test['HeatingQC'] = test['HeatingQC'].replace("TA", 3.0) 
test['HeatingQC'] = test['HeatingQC'].replace("Gd", 4.0) 
test['HeatingQC'] = test['HeatingQC'].replace("Ex", 5.0)

# %%
test['CentralAir'] = dftest['CentralAir']

# %%
test['CentralAir'] = test['CentralAir'].replace("Y", 1.0)
test['CentralAir'] = test['CentralAir'].replace("N", 0)

# %%
test = test.join(pd.get_dummies(dftest['GarageType']))

# %%
test = test.join(pd.get_dummies(dftest['SaleType']))

# %%
test = test.join(pd.get_dummies(dftest['SaleCondition']))

# %%
test['WoodDeckSF'] = dftest['WoodDeckSF']

# %%
test['OpenPorchSF'] = dftest['OpenPorchSF']

# %%
test = test.join(pd.get_dummies(dftest['Exterior1st']))

# %%
test['ExterQual'] = dftest['ExterQual']

# %%
test['ExterQual'] = test['ExterQual'].replace("Po", 1.0) 
test['ExterQual'] = test['ExterQual'].replace("Fa", 2.0) 
test['ExterQual'] = test['ExterQual'].replace("TA", 3.0) 
test['ExterQual'] = test['ExterQual'].replace("Gd", 4.0) 
test['ExterQual'] = test['ExterQual'].replace("Ex", 5.0)

# %%
test = test.join(pd.get_dummies(dftest['Electrical']))

# %%
test
# Out:
#       MSSubClass  OverallQual  OverallCond  YearBuilt  1stFlrSF  2ndFlrSF  \
# 0      -0.874411    -0.750844     0.400629  -0.340828 -0.654337 -0.774988
# 1      -0.874411    -0.054858     0.400629  -0.439544  0.433150 -0.774988
# 2       0.061330    -0.750844    -0.497247   0.843770 -0.573968  0.891638
# 3       0.061330    -0.054858     0.400629   0.876675 -0.578991  0.836956
# 4       1.464941     1.337113    -0.497247   0.679242  0.310085 -0.774988
# 5       0.061330    -0.054858    -0.497247   0.712148 -0.988369  1.345740
# 6      -0.874411    -0.054858     1.298505   0.679242  0.076514 -0.774988
# 7       0.061330    -0.054858    -0.497247   0.876675 -0.923069  0.832201
# 8      -0.874411     0.641127    -0.497247   0.613431  0.463288 -0.774988
# 9      -0.874411    -1.446829    -0.497247  -0.044678 -0.689498 -0.774988
# 10      1.464941     0.641127    -0.497247   0.909581  0.453242 -0.774988
# 11      2.400682    -0.054858    -0.497247  -0.011773 -1.691593  0.423271
# ...

# %%
dfna = test[test.isna().any(axis=1)]

# %%
dfna
# Out:
# Empty DataFrame
# Columns: [MSSubClass, OverallQual, OverallCond, YearBuilt, 1stFlrSF, 2ndFlrSF, GrLivArea, FullBath, HalfBath, ScreenPorch, YrSold, C (all), FV, RH, RL, RM, LotArea, Street, Utilities, Corner, CulDSac, FR2, FR3, Inside, Blmngtn, Blueste, BrDale, BrkSide, ClearCr, CollgCr, Crawfor, Edwards, Gilbert, IDOTRR, MeadowV, Mitchel, NAmes, NPkVill, NWAmes, NoRidge, NridgHt, OldTown, SWISU, Sawyer, SawyerW, Somerst, StoneBr, Timber, Veenker, 1Fam, 2fmCon, Duplex, Twnhs, TwnhsE, HouseStyle, BsmtCond, HeatingQC, CentralAir, 2Types, Attchd, Basment, BuiltIn, CarPort, Detchd, COD, CWD, Con, ConLD, ConLI, ConLw, New, Oth, WD, Abnorml, AdjLand, Alloca, Family, Normal, Partial, WoodDeckSF, OpenPorchSF, AsbShng, AsphShn, BrkComm, BrkFace, CBlock, CemntBd, HdBoard, MetalSd, Plywood, Stucco, VinylSd, Wd Sdng, WdShing, ExterQual, FuseA, FuseF, FuseP, SBrkr]
# Index: []
#
# [0 rows x 99 columns]

# %%
test.fillna(0,inplace=True)

# %%
lasso.fit(X_train, y_train)
# Out:
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 609940088491.6921, tolerance: 920791133.4609977
#   positive)
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %% [markdown]
# <h1>Submission File Creation</h1>

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=0.4, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=2, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
test.columns
# Out:
# Index(['MSSubClass', 'OverallQual', 'OverallCond', 'YearBuilt', '1stFlrSF',
#        '2ndFlrSF', 'GrLivArea', 'FullBath', 'HalfBath', 'ScreenPorch',
#        'YrSold', 'C (all)', 'FV', 'RH', 'RL', 'RM', 'LotArea', 'Street',
#        'Utilities', 'Corner', 'CulDSac', 'FR2', 'FR3', 'Inside', 'Blmngtn',
#        'Blueste', 'BrDale', 'BrkSide', 'ClearCr', 'CollgCr', 'Crawfor',
#        'Edwards', 'Gilbert', 'IDOTRR', 'MeadowV', 'Mitchel', 'NAmes',
#        'NPkVill', 'NWAmes', 'NoRidge', 'NridgHt', 'OldTown', 'SWISU', 'Sawyer',
#        'SawyerW', 'Somerst', 'StoneBr', 'Timber', 'Veenker', '1Fam', '2fmCon',
#        'Duplex', 'Twnhs', 'TwnhsE', 'HouseStyle', 'BsmtCond', 'HeatingQC',
#        'CentralAir', '2Types', 'Attchd', 'Basment', 'BuiltIn', 'CarPort',
#        'Detchd', 'COD', 'CWD', 'Con', 'ConLD', 'ConLI', 'ConLw', 'New', 'Oth',
#        'WD', 'Abnorml', 'AdjLand', 'Alloca', 'Family', 'Normal', 'Partial',
# ...

# %%
test['Stone'] = 0
test['PreCast'] = 0
test['Other'] = 0

# %%
test.drop(['Prediction'], axis = 1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-654-19717301bf0b> in <module>
# ----> 1 test.drop(['Prediction'], axis = 1,inplace=True)
#
# X:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# X:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
test
# Out:
#       MSSubClass  OverallQual  OverallCond  YearBuilt  1stFlrSF  2ndFlrSF  \
# 0      -0.874411    -0.750844     0.400629  -0.340828 -0.654337 -0.774988
# 1      -0.874411    -0.054858     0.400629  -0.439544  0.433150 -0.774988
# 2       0.061330    -0.750844    -0.497247   0.843770 -0.573968  0.891638
# 3       0.061330    -0.054858     0.400629   0.876675 -0.578991  0.836956
# 4       1.464941     1.337113    -0.497247   0.679242  0.310085 -0.774988
# 5       0.061330    -0.054858    -0.497247   0.712148 -0.988369  1.345740
# 6      -0.874411    -0.054858     1.298505   0.679242  0.076514 -0.774988
# 7       0.061330    -0.054858    -0.497247   0.876675 -0.923069  0.832201
# 8      -0.874411     0.641127    -0.497247   0.613431  0.463288 -0.774988
# 9      -0.874411    -1.446829    -0.497247  -0.044678 -0.689498 -0.774988
# 10      1.464941     0.641127    -0.497247   0.909581  0.453242 -0.774988
# 11      2.400682    -0.054858    -0.497247  -0.011773 -1.691593  0.423271
# ...

# %%
test['Prediction'] = rf.predict(test)

# %%
output = pd.DataFrame({
    'Id'       : np.arange(1461, 2920),
    'SalePrice': np.exp(test.Prediction)
})

# %%
output["SalePrice"] = test.Prediction

# %%
output
# Out:
#         Id      SalePrice
# 0     1461  120050.343333
# 1     1462  160657.280952
# 2     1463  176293.442381
# 3     1464  182798.516667
# 4     1465  192926.833333
# 5     1466  191971.720714
# 6     1467  172751.644722
# 7     1468  178698.653714
# 8     1469  179040.359603
# 9     1470  114220.136190
# 10    1471  186340.832937
# 11    1472   96051.816306
# 12    1473   93547.818766
# 13    1474  149886.521190
# 14    1475  136248.486190
# 15    1476  346813.928563
# 16    1477  256020.973230
# 17    1478  285085.453992
# 18    1479  281735.968230
# 19    1480  378834.945302
# 20    1481  304297.349230
# 21    1482  205643.369976
# 22    1483  180005.972548
# 23    1484  170856.025179
# 24    1485  174953.102571
# 25    1486  201097.534952
# 26    1487  314985.359444
# 27    1488  239298.541897
# 28    1489  195900.624238
# 29    1490  193123.692381
# ...    ...            ...
# 1429  2890   84048.655754
# 1430  2891  140593.134222
# 1431  2892   69136.727405
# ...

# %%
output.to_csv('real_predictions.csv',index=False)

# %% [markdown]
# <h1>Model Tuning</h1>

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 0.5,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
samples_per_leaf = [1, 5, 10, 15, 25, 50]
rf_scores = []


for num_samples in samples_per_leaf:
    rf.set_params(min_samples_leaf=num_samples)
    scores5 = cross_val_score(estimator=rf, X=X_train, y=y_train, cv=10)
    rf_scores.append((np.mean(scores5), num_samples))

# %%
rf_scores
# Out:
# [(0.8631545693603325, 1),
#  (0.8415711069989499, 5),
#  (0.833072185908874, 10),
#  (0.8282188391190122, 15),
#  (0.8094238180343988, 25),
#  (0.7635836413262203, 50)]

# %%
rf.set_params(min_samples_leaf=2)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=0.5, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=2, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=200,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
n_estimators = [10, 25, 50, 100, 200]
rf_scores = []


for numestimators in n_estimators:
    rf.set_params(n_estimators=numestimators)
    scores5 = cross_val_score(estimator=rf, X=X_train, y=y_train, cv=10)
    rf_scores.append((np.mean(scores5), numestimators))

# %%
rf_scores
# Out:
# [(0.8348799141113888, 10),
#  (0.8597969824139164, 25),
#  (0.8533297795165075, 50),
#  (0.8576960152320975, 100),
#  (0.8545998172676195, 200)]

# %%
rf.set_params(n_estimators = 100)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=0.5, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=2, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
features = [0.2, 0.4, 0.5, 0.6, 0.7]
rf_scores = []


for n_features in features:
    rf.set_params(max_features=n_features)
    scores5 = cross_val_score(estimator=rf, X=X_train, y=y_train, cv=10)
    rf_scores.append((np.mean(scores5), n_features))

# %%
rf_scores
# Out:
# [(0.8505765632721513, 0.2),
#  (0.8564891332724061, 0.4),
#  (0.8548142479969858, 0.5),
#  (0.8522913351340129, 0.6),
#  (0.8503728276219841, 0.7)]

# %%
rf.set_params(max_features = 0.4)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=0.4, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=2, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)
