# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv('productsprocessed1.csv')
#standardize the data
#df=(df-df.mean())/df.std()
#standardizing actually gave me a lower score on the final test (around .18)

# %%
df
# Out:
#        Unnamed: 0  early_access  price  sentiment  Accounting  Action  \
# 0               0           0.0   0.00          5           0       1
# 1               1           1.0  24.99          6           0       0
# 2               2           0.0   4.99          5           0       1
# 3               3           0.0   4.99          5           0       0
# 4               4           1.0   9.99          5           0       0
# 5               5           0.0   9.99          5           0       0
# 6               6           0.0   3.99          5           0       0
# 7               7           1.0   9.99          5           0       0
# 8               8           0.0   0.00          5           0       1
# 9               9           1.0  14.99          5           0       0
# 10             10           0.0   4.99          5           0       0
# 11             11           0.0  10.99          5           0       0
# ...

# %%
df_train = df.iloc[1000:,:]
df_test = df.iloc[:1000,:]

# %%
#importing 
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge, Lasso

rf = RandomForestRegressor()
rreg= Ridge()
lasso = Lasso()

# %%
X_train = df_train.drop('price',axis = 1)
y_train = df_train['price']

# %%
from sklearn.model_selection import cross_val_score
#you can use fit and predict method from other models beside sklearn
scores = cross_val_score(estimator=rf, X=X_train, y=y_train, cv=10)
# Out:
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
scores.var()
# Out:
# 0.1869633802905498

# %%
scores.mean()
# Out:
# -0.19310220705348316

# %%
scores2 = cross_val_score(estimator=rreg, X=X_train, y=y_train, cv=10)

# %%
scores2.var()
# Out:
# 0.004908888565710073

# %%
scores2.mean()
# Out:
# 0.161718479160584

# %%
scores3 = cross_val_score(estimator=lasso, X=X_train, y=y_train, cv=10)

# %%
scores3.var()
# Out:
# 0.0002649066120905322

# %%
scores3.mean()
# Out:
# 0.030381905564308052

# %%
#Ridge regression did the best, let's see if we can improve it.

rreg.get_params()
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': None,
#  'normalize': False,
#  'random_state': None,
#  'solver': 'auto',
#  'tol': 0.001}

# %%
alphas = np.logspace(-4, 4, 9)
cv_scores = []

for alpha in alphas:
    rreg.set_params(alpha=alpha)
    scores = cross_val_score(estimator=rreg, X=X_train, y=y_train, cv=10)
    cv_scores.append((np.mean(scores), alpha))
# Out:
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.28469e-17): result may not be accurate.
#   overwrite_a=True).T
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.67133e-17): result may not be accurate.
#   overwrite_a=True).T
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.26962e-17): result may not be accurate.
#   overwrite_a=True).T
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.02337e-17): result may not be accurate.
#   overwrite_a=True).T
# X:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.90848e-17): result may not be accurate.
#   overwrite_a=True).T
# ...

# %%
cv_scores
# Out:
# [(0.16073753653554734, 0.0001),
#  (0.16073850269603082, 0.001),
#  (0.1607481542457973, 0.01),
#  (0.16084369412295585, 0.1),
#  (0.161718479160584, 1.0),
#  (0.1664404459987217, 10.0),
#  (0.17131111904658858, 100.0),
#  (0.164100430784664, 1000.0),
#  (0.11137176304440992, 10000.0)]

# %%
rreg.set_params(alpha=1000)
# Out:
# Ridge(alpha=1000, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
scores4 = cross_val_score(estimator=rreg, X=X_train, y=y_train, cv=10)

# %%
scores4.mean()
# Out:
# 0.164100430784664

# %%
X_test = df_test.drop('price',axis = 1)
y_test = df_test['price']

# %%
rreg.fit(X_train, y_train)
# Out:
# Ridge(alpha=1000, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
#the moment of truth 
rreg.score(X_test, y_test)
# Out:
# 0.20343671712875422
